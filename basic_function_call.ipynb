# %%
from lib.symbolic_model import symbolic_model
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/ame2020.csv')

Z_all_z_12 = []
N_all_z_12 = []
for n,z,be,be_unc in zip(df.n,df.z,df.binding,df.binding_unc):
    if (be_unc * (z + n) > 100):
        continue
    if (z>=12):
        Z_all_z_12.append(z)
        N_all_z_12.append(n)
    
N_all_z_12 = np.array(N_all_z_12)
Z_all_z_12 = np.array(Z_all_z_12)

# %%
model = symbolic_model(Z_all_z_12,N_all_z_12)
plt.figure(figsize=(4,5))
plt.scatter(Z_all_z_12, N_all_z_12, c=model, cmap="viridis", s=4, marker="s")
plt.colorbar()
plt.show()
